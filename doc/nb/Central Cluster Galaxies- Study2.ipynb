# %%
import fitsio
from astropy.table import Table
from astropy.io import fits
from astropy.io import ascii
from matplotlib import pyplot as plt
from astropy.utils.data import download_file
import numpy as np
from pandas import DataFrame
import matplotlib.image as mpimg
# %matplotlib notebook

# %%
#pcen0 is a file containing the central galaxies that has a probability < 0.3
selections = fitsio.FITS('/home/ghadeer/pcen0.fits')
print(selections)
data = Table(selections[1].read())
data
# Out:
#   file: /home/ghadeer/pcen0.fits
#   mode: READONLY
#   extnum hdutype         hduname[v]
#   0      IMAGE_HDU
#   1      BINARY_TBL
# <Table length=16>
#         RA                 DEC          MEM_MATCH_ID
#      float64             float64           int32
# ------------------ -------------------- ------------
# 318.43229604260847  -2.3977915634401707         5277
#  247.9668418644738    48.67883539652901         6351
# 153.88982657467585   14.464745159260914         8168
# 171.89483557329794   2.4785495428210824        12435
# 134.54291072559377   25.409522504112115        12566
# 13.467203067939806   26.374518735557736        14285
# 335.91668160048835   1.8187917100100757        14875
# 230.08636615903637    6.383899004075871        18540
#    14.140293027241    2.135342052349959        20913
# 124.20657651557993    40.06760481556991        21248
# 171.08842186043967   42.360298841940406        22383
# 200.00011451480395   45.267450933455585        23585
# ...

# %%
#The cluster that coresponds with these coordinates is: ID#5277
# we extracted the details of this cluster from both the whole and the central galaxies files.
parent_mem = fitsio.FITS('/home/ghadeer/whole_members.fit')
members = Table(parent_mem[1].read())
members[members['MEM_MATCH_ID'] == 5277]['RA','DEC','MEM_MATCH_ID'].write('mem5277.fit', overwrite = True)
#-------------------------------------------------------------------------------------------------------
central_mem = fitsio.FITS('/home/ghadeer/central.fit')
members_cen = Table(central_mem[1].read())
members_cen[members_cen['MEM_MATCH_ID'] == 5277]['RA','DEC','MEM_MATCH_ID','RA_CENT','DEC_CENT','P_CEN'].write('cen5277.fit', overwrite = True)

# %%
#To read the new files and display them in tables.
index_mem = fitsio.FITS('/home/ghadeer/mem5277.fit')
sample_0mem = Table(index_mem[1].read())
index_cen = fitsio.FITS('/home/ghadeer/cen5277.fit')
sample_0cen = Table(index_cen[1].read())

# %%
sample_0cen
# Out:
# <Table length=1>
#         RA                 DEC         ...        P_CEN [5]
#      float64             float64       ...         float32
# ------------------ ------------------- ... ------------------------
# 318.43229604260847 -2.3977915634401707 ... 0.27811548 .. 0.09235255

# %%
#The first photo shows the whole cluster
cluster_2532 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample0-T3/0.png')
plt.imshow(cluster_2532)
plt.show()

#The second shows the central galaxy in RedMapper
cen_2532 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample0-T3/0cen.png')
plt.imshow(cen_2532)
plt.show()

# %% [markdown]
# The selection looks reasonable with a P_CEN = 0.278

# %%
#The cluster that coresponds with these coordinates is: ID#6351
# we extracted the details of this cluster from both the whole and the central galaxies files.
parent_mem = fitsio.FITS('/home/ghadeer/whole_members.fit')
members = Table(parent_mem[1].read())
members[members['MEM_MATCH_ID'] == 6351]['RA','DEC','MEM_MATCH_ID'].write('mem6351.fit', overwrite = True)
#-------------------------------------------------------------------------------------------------------
central_mem = fitsio.FITS('/home/ghadeer/central.fit')
members_cen = Table(central_mem[1].read())
members_cen[members_cen['MEM_MATCH_ID'] == 6351]['RA','DEC','MEM_MATCH_ID','RA_CENT','DEC_CENT','P_CEN'].write('cen6351.fit', overwrite = True)

# %%
#To read the new files and display them in tables.
index_mem = fitsio.FITS('/home/ghadeer/mem6351.fit')
sample_1mem = Table(index_mem[1].read())
index_cen = fitsio.FITS('/home/ghadeer/cen6351.fit')
sample_1cen = Table(index_cen[1].read())
sample_1cen
# Out:
# <Table length=1>
#         RA               DEC        ...        P_CEN [5]
#      float64           float64      ...         float32
# ----------------- ----------------- ... ------------------------
# 247.9668418644738 48.67883539652901 ... 0.2996301 .. 0.052891895

# %%
#The first photo shows the whole cluster
cluster_6351 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample1-T3/1.png')
plt.imshow(cluster_6351)
plt.show()

#The second shows the central galaxy in RedMapper
cen_6351 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample1-T3/1cen.png')
plt.imshow(cen_6351)
plt.show()

# %% [markdown]
# This chosen central galaxy also looks reasonable with a P_CEN = 0.299

# %%
#The cluster that coresponds with these coordinates is: ID#8168
# we extracted the details of this cluster from both the whole and the central galaxies files.
parent_mem = fitsio.FITS('/home/ghadeer/whole_members.fit')
members = Table(parent_mem[1].read())
members[members['MEM_MATCH_ID'] == 8168]['RA','DEC','MEM_MATCH_ID'].write('mem8168.fit', overwrite = True)
#-------------------------------------------------------------------------------------------------------
central_mem = fitsio.FITS('/home/ghadeer/central.fit')
members_cen = Table(central_mem[1].read())
members_cen[members_cen['MEM_MATCH_ID'] == 8168]['RA','DEC','MEM_MATCH_ID','RA_CENT','DEC_CENT','P_CEN'].write('cen8168.fit', overwrite = True)

# %%
#To read the new files and display them in tables.
index_mem = fitsio.FITS('/home/ghadeer/mem8168.fit')
sample_2mem = Table(index_mem[1].read())
index_cen = fitsio.FITS('/home/ghadeer/cen8168.fit')
sample_2cen = Table(index_cen[1].read())
sample_2cen
# Out:
# <Table length=1>
#         RA                DEC         ...        P_CEN [5]
#      float64            float64       ...         float32
# ------------------ ------------------ ... ------------------------
# 153.88982657467585 14.464745159260914 ... 0.27512503 .. 0.14898647

# %%
#The first photo shows the whole cluster
cluster_8168 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample2-T3/2.png')
plt.imshow(cluster_8168)
plt.show()

#The second shows the central galaxy in RedMapper
cen_8168 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample2-T3/2cen.png')
plt.imshow(cen_8168)
plt.show()

# %% [markdown]
# I believe there is a good chance one of the other galaxies can be a better candidate than the above which has a PCEN = 0.275

# %%
#The cluster that coresponds with these coordinates is: ID#12435
# we extracted the details of this cluster from both the whole and the central galaxies files.
parent_mem = fitsio.FITS('/home/ghadeer/whole_members.fit')
members = Table(parent_mem[1].read())
members[members['MEM_MATCH_ID'] == 12435]['RA','DEC','MEM_MATCH_ID'].write('mem12435.fit', overwrite = True)
#-------------------------------------------------------------------------------------------------------
central_mem = fitsio.FITS('/home/ghadeer/central.fit')
members_cen = Table(central_mem[1].read())
members_cen[members_cen['MEM_MATCH_ID'] == 12435]['RA','DEC','MEM_MATCH_ID','RA_CENT','DEC_CENT','P_CEN'].write('cen12435.fit', overwrite = True)

# %%
#To read the new files and display them in tables.
index_mem = fitsio.FITS('/home/ghadeer/mem12435.fit')
sample_3mem = Table(index_mem[1].read())
index_cen = fitsio.FITS('/home/ghadeer/cen12435.fit')
sample_3cen = Table(index_cen[1].read())
sample_3cen
# Out:
# <Table length=1>
#         RA                DEC         ...        P_CEN [5]
#      float64            float64       ...         float32
# ------------------ ------------------ ... -----------------------
# 171.89483557329794 2.4785495428210824 ... 0.2668939 .. 0.07325537

# %%
#The first photo shows the whole cluster
cluster_12435 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample3-T3/3.png')
plt.imshow(cluster_12435)
plt.show()

#The second shows the central galaxy in RedMapper
cen_12435 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample3-T3/3cen.png')
plt.imshow(cen_12435)
plt.show()

# %% [markdown]
# The selection looks reasonable at PCEN = 0.266

# %%
#The cluster that coresponds with these coordinates is: ID#12566
# we extracted the details of this cluster from both the whole and the central galaxies files.
parent_mem = fitsio.FITS('/home/ghadeer/whole_members.fit')
members = Table(parent_mem[1].read())
members[members['MEM_MATCH_ID'] == 12566]['RA','DEC','MEM_MATCH_ID'].write('mem12566.fit', overwrite = True)
#-------------------------------------------------------------------------------------------------------
central_mem = fitsio.FITS('/home/ghadeer/central.fit')
members_cen = Table(central_mem[1].read())
members_cen[members_cen['MEM_MATCH_ID'] == 12566]['RA','DEC','MEM_MATCH_ID','RA_CENT','DEC_CENT','P_CEN'].write('cen12566.fit', overwrite = True)

# %%
#To read the new files and display them in tables.
index_mem = fitsio.FITS('/home/ghadeer/mem12566.fit')
sample_4mem = Table(index_mem[1].read())
index_cen = fitsio.FITS('/home/ghadeer/cen12566.fit')
sample_4cen = Table(index_cen[1].read())
sample_4cen
# Out:
# <Table length=1>
#         RA                DEC         ...        P_CEN [5]
#      float64            float64       ...         float32
# ------------------ ------------------ ... ------------------------
# 134.54291072559377 25.409522504112115 ... 0.29257905 .. 0.12319985

# %%
#The first photo shows the whole cluster
cluster_12566 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample4-T3/4.png')
plt.imshow(cluster_12566)
plt.show()

#The second shows the central galaxy in RedMapper
cen_12566 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample4-T3/4cen.png')
plt.imshow(cen_12566)
plt.show()

# %% [markdown]
# The selcetion is very reasonable at PCEN = 0.292

# %%
#The cluster that coresponds with these coordinates is: ID#14285
# we extracted the details of this cluster from both the whole and the central galaxies files.
parent_mem = fitsio.FITS('/home/ghadeer/whole_members.fit')
members = Table(parent_mem[1].read())
members[members['MEM_MATCH_ID'] == 14285]['RA','DEC','MEM_MATCH_ID'].write('mem14285.fit', overwrite = True)
#-------------------------------------------------------------------------------------------------------
central_mem = fitsio.FITS('/home/ghadeer/central.fit')
members_cen = Table(central_mem[1].read())
members_cen[members_cen['MEM_MATCH_ID'] == 14285]['RA','DEC','MEM_MATCH_ID','RA_CENT','DEC_CENT','P_CEN'].write('cen14285.fit', overwrite = True)

# %%
#To read the new files and display them in tables.
index_mem = fitsio.FITS('/home/ghadeer/mem14285.fit')
sample_5mem = Table(index_mem[1].read())
index_cen = fitsio.FITS('/home/ghadeer/cen14285.fit')
sample_5cen = Table(index_cen[1].read())
sample_5cen
# Out:
# <Table length=1>
#         RA                DEC         ...        P_CEN [5]
#      float64            float64       ...         float32
# ------------------ ------------------ ... ------------------------
# 13.467203067939806 26.374518735557736 ... 0.25786814 .. 0.11066277

# %%
#The first photo shows the whole cluster
cluster_14285 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample5-T3/5.png')
plt.imshow(cluster_14285)
plt.show()

#The second shows the central galaxy in RedMapper
cen_14285 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample5-T3/5cen.png')
plt.imshow(cen_14285)
plt.show()

# %% [markdown]
# The selection is very weak at PCEN = 0.257, there are much more better candidates around it.

# %%
#The cluster that coresponds with these coordinates is: ID#14875
# we extracted the details of this cluster from both the whole and the central galaxies files.
parent_mem = fitsio.FITS('/home/ghadeer/whole_members.fit')
members = Table(parent_mem[1].read())
members[members['MEM_MATCH_ID'] == 14875]['RA','DEC','MEM_MATCH_ID'].write('mem14875.fit', overwrite = True)
#-------------------------------------------------------------------------------------------------------
central_mem = fitsio.FITS('/home/ghadeer/central.fit')
members_cen = Table(central_mem[1].read())
members_cen[members_cen['MEM_MATCH_ID'] == 14875]['RA','DEC','MEM_MATCH_ID','RA_CENT','DEC_CENT','P_CEN'].write('cen14875.fit', overwrite = True)

# %%
#To read the new files and display them in tables.
index_mem = fitsio.FITS('/home/ghadeer/mem14875.fit')
sample_6mem = Table(index_mem[1].read())
index_cen = fitsio.FITS('/home/ghadeer/cen14875.fit')
sample_6cen = Table(index_cen[1].read())
sample_6cen
# Out:
# <Table length=1>
#         RA                DEC         ...         P_CEN [5]
#      float64            float64       ...          float32
# ------------------ ------------------ ... -------------------------
# 335.91668160048835 1.8187917100100757 ... 0.26754734 .. 0.014446641

# %%
#The first photo shows the whole cluster
cluster_14875 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample6-T3/6.png')
plt.imshow(cluster_14875)
plt.show()

#The second shows the central galaxy in RedMapper
cen_14875 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample6-T3/6cen.png')
plt.imshow(cen_14875)
plt.show()

# %% [markdown]
# Other galaxies have better chance of being the central thank the selected at PCEN=0.267

# %%
#The cluster that coresponds with these coordinates is: ID#18540
# we extracted the details of this cluster from both the whole and the central galaxies files.
parent_mem = fitsio.FITS('/home/ghadeer/whole_members.fit')
members = Table(parent_mem[1].read())
members[members['MEM_MATCH_ID'] == 18540]['RA','DEC','MEM_MATCH_ID'].write('mem18540.fit', overwrite = True)
#-------------------------------------------------------------------------------------------------------
central_mem = fitsio.FITS('/home/ghadeer/central.fit')
members_cen = Table(central_mem[1].read())
members_cen[members_cen['MEM_MATCH_ID'] == 18540]['RA','DEC','MEM_MATCH_ID','RA_CENT','DEC_CENT','P_CEN'].write('cen18540.fit', overwrite = True)

# %%
#To read the new files and display them in tables.
index_mem = fitsio.FITS('/home/ghadeer/mem18540.fit')
sample_7mem = Table(index_mem[1].read())
index_cen = fitsio.FITS('/home/ghadeer/cen18540.fit')
sample_7cen = Table(index_cen[1].read())
sample_7cen
# Out:
# <Table length=1>
#         RA                DEC        ...        P_CEN [5]
#      float64            float64      ...         float32
# ------------------ ----------------- ... -----------------------
# 230.08636615903637 6.383899004075871 ... 0.2988455 .. 0.09993382

# %%
#The first photo shows the whole cluster
cluster_18540 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample7-T3/7.png')
plt.imshow(cluster_18540)
plt.show()

#The second shows the central galaxy in RedMapper
cen_18540 = mpimg.imread('/home/ghadeer/Desktop/CCG-Study/Sample7-T3/7cen.png')
plt.imshow(cen_18540)
plt.show()

# %% [markdown]
# The selected central galaxy is reasonable with a PCEN = 0.298

# %% [markdown]
# I have noticed that anythin near PCEN = 0.3 is a reasonable central galaxy selection
